# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
from pytesseract import Output

# %%
from PIL import Image
import pytesseract, re
f = "/kaggle/input/timage/testreport.jpg"
t = pytesseract.image_to_data(Image.open(f),output_type=Output.DICT,lang="eng")

# %%
t.keys()

# %%
 total_boxes = len(t['text'])

# %%
total_boxes

# %%
parse_text = []
word_list = []
last_word = ''

for word in t['text']:
    
    if word!='':
#           if(word=='Name' or word =='Age' or word=='Blood Glucose(F)' or word=='Blood Glucose(PP)'):
        word_list.append(word)
        last_word = word
        
    if (last_word!='' and word == '') or (word==t['text'][-1]):
        
        parse_text.append(word_list)
        word_list = []

# %%
word_list

# %%
parse_text[4][0]

# %%
new_list=[]

# %%
x=0

# %%
parse_text

# %%
list2 = [x for x in parse_text if x != []]

# %%
list2

# %% [raw]
# len(parse_text)

# %%
new_dict={}

# %%
for i in range(len(list2)):
        
    if(list2[i][0]=='Name'):
        new_dict['Name']=list2[i][2]
#         new_list.append(list2[i][2])
        
    elif(list2[i][0]=='Age'):
        new_dict['Age']=list2[i][2]
#         new_list.append(list2[i][2])
        
    elif(list2[i][0]=='Date'):
        new_dict['Date']=list2[i][2]
#         new_list.append(list2[i][2])
    
    elif(list2[i][0]=='Sex'):
        new_dict['Sex']=list2[i][2]
        
    elif(list2[i][0]=='Blood'):
        s=str(list2[i][0])+str(list2[i][1])
        new_dict[s]=list2[i][2]
        new_dict[s]=list2[i][3]
#         new_list.append(list2[i][2])

# %%
new_dict
# Out:
# {'Name': 'Mr.GEORGE.E.M.',
#  'Age': '66',
#  'Sex': 'Male',
#  'BloodGlucose(F)': '90.0',
#  'BloodGlucose(PP)': '73.0'}

# %%
import csv
with open('result_text.txt',  'w', newline="") as file:
    csv.writer(file, delimiter=" ").writerows(new_list)

# %%
from PIL import Image
import pytesseract, re
f = "../input/timage19/teststreport6.JPG"
t1 = pytesseract.image_to_data(Image.open(f),output_type=Output.DICT,lang="eng")

# %%
parse_text1 = []
word_list1 = []
last_word1 = ''

for word in t1['text']:
    
    if word!='':
#           if(word=='Name' or word =='Age' or word=='Blood Glucose(F)' or word=='Blood Glucose(PP)'):
        word_list1.append(word)
        last_word1= word
        
    if (last_word!='' and word == '') or (word==t1['text'][-1]):
        
        parse_text1.append(word_list1)
        word_list1= []

# %%
list3 = [x for x in parse_text1 if x != []]

# %%
list3
# Out:
# [['Date', ':', '28/05/20'],
#  ['Reg', 'No.', ':', '89785656789'],
#  ['Name', ':', 'Maxwell'],
#  ['Age', ':', '20'],
#  ['Gender', ':', 'Male'],
#  ['Final', 'Test', 'Report'],
#  ['Test', 'Name', 'Observed', 'Value'],
#  ['Biological', 'Range'],
#  ['Haemoglobin', '9.1.', 'g/dl', '12-17'],
#  ['RBC', '3.74', 'millions/mm3', '4.5-6.0'],
#  ['Platelet', 'Count', '6.5', 'lakhs/mcL', '1.5:', '4.0']]

# %%
list3[1][0]
# Out:
# 'Reg'

# %%
new_dict1={}

# %%
ans=False

# %%
for i in range(len(list3)):
        
    if(list3[i][0]=='Name'):
        new_dict1['Name']=list3[i][2]
        
    elif(list3[i][0]=='Age'):
        new_dict1['Age']=list3[i][2]

        
    elif(list3[i][0]=='Date'):
        new_dict1['Date']=list3[i][2]

    elif(list3[i][0]=='Haemoglobin'):
        new_dict1['Haemoglobin']=list3[i][1]
        
    elif(list3[i][0]=='RBC'):
        new_dict1['RBC']=list3[i][1]
        
    elif(list3[i][0]=='Platelet'):
        new_dict1['Platelet Count']=list3[i][2]
    
    elif(list3[i][0]=='Gender;' or list3[i][0]=='Gender:'):
        new_dict1['Gender']=list3[i][1]
    
    elif(list3[i][0]=='Gender'):
        new_dict1['Gender']=list3[i][2]
        
    if(len(list3[i])>=2):
        
        if(list3[i][1]=="mgs/dt" or list3[i][1]=='mgs/dl' and not ans):
            
            new_dict1['Blood Glucose(F)']=list3[i][0]
            new_dict1['Blood Glucose(PP)']=list3[i+1][0]
            ans=True

      
    
#     elif(list3[i][0]=='Blood'):
#         s=str(list3[i][0])+str(list3[i][1])
#         new_dict1[s]=list3[i][2]
#         new_dict1[s]=list3[i][3]

# %%
new_dict1
# Out:
# {'Date': '28/05/20',
#  'Name': 'Maxwell',
#  'Age': '20',
#  'Gender': 'Male',
#  'Haemoglobin': '9.1.',
#  'RBC': '3.74',
#  'Platelet Count': '6.5'}

# %%
from PIL import Image
import pytesseract, re
f = "../input/timage2/new.jpg"
t = pytesseract.image_to_string(Image.open(f))
m = re.findall(r"MASTER-AIRWAYBILL NO: [\d++]--", t)
if m:
    print(m[0])
